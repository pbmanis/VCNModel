# %%
from neuron import gui2, h, rxd
print(dir(gui2))
# Out:
# ['PlotShape', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'plotshape', 'set_backend']

# %%
gui2.set_backend('jupyter')
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
h.hoc_stdout('/dev/null')
x = h.load_file('/Users/pbmanis/Desktop/Python/VCN-SBEM-Data/VCN_Cells/VCN_c11/Morphology/VCN_c11_Full.hoc', '1')
h.hoc_stdout()
# Out:
# 1.0

# %%
# ps = gui2.PlotShape()
# ps.variable('v')
# ps.show(0)

# %%
h.topology()
# Out:
# |-|       sections[0](0-1)
#    `|       sections[1](0-1)
#      `|       sections[2](0-1)
#        `|       sections[3](0-1)
#          `|       sections[4](0-1)
#            `|       sections[5](0-1)
#              `|       sections[6](0-1)
#                `|       sections[7](0-1)
#                  `|       sections[8](0-1)
#                    `|       sections[9](0-1)
#                      `|       sections[10](0-1)
#                    `|       sections[11](0-1)
#                      `|       sections[12](0-1)
#                        `|       sections[13](0-1)
#                          `|       sections[14](0-1)
#                            `|       sections[15](0-1)
#                    `|       sections[16](0-1)
#                    `|       sections[17](0-1)
#                    `|       sections[18](0-1)
#                      `|       sections[19](0-1)
#                        `|       sections[20](0-1)
#                          `|       sections[21](0-1)
# ...
